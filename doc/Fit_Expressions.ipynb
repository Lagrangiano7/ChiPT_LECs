# %% [markdown]
# 1. $\phi_{12}=\phi_2\left[p_1+p_2\phi_2+p_3 K (\mathcal L_2-\frac{1}{3}\mathcal L_\eta)\right]+\frac{a^2}{8t_0}[C_0+C_1\phi_2]$
#
# - $p_1=\frac{1}{2B_0\sqrt {8t_0}}\left[1-\frac{32}{8t_0f_0^2}(2L_6-L_4)\phi_4\right]$
# - $p_2=-\frac{1}{2B_0\sqrt{8t_0}}\frac{16}{8t_0f_0^2}(2L_8-L_5)$
# - $p_3=-\frac{1}{2B_0\sqrt{8t_0}}$
# - $K=\frac{1}{8t_016\pi^2f_0^2}$
# - $\mathcal L_i=\phi_i\log\phi_i$
#
# 2. $\phi_{13}=\phi_K\left[p_1+p_2\phi_K+\frac{2}{3}p_3 K \mathcal L_\eta)\right]+\frac{a^2}{8t_0}[\tilde C_0+\tilde C_1\phi_2]$
#
# - $\phi_k=\frac{2\phi_4-\phi_2}{2}$

# %% [markdown]
# 3. $\phi_{\pi K}^{cont}=\sqrt{8t_0}f_{\pi K}^{cont}=\frac{A}{4\pi}\left[1-\frac{7}{6}\mathcal L\left(\frac{\phi_2}{A^2}\right)-\frac{4}{3}\mathcal L\left(\frac{\phi_4-\frac{1}{2}\phi_2}{A^2}\right)-\frac{1}{2}\mathcal L\left(\frac{\frac{4}{3}\phi_4-\phi_2}{A^2}\right)+\frac{B}{A^2}\phi_4\right]$
#
# - $A=4\pi\sqrt{8t_{0,ch}}f_0$
# - $B=\frac{(16\pi)^2}{3}(L_5+3L_4)+k_1$
